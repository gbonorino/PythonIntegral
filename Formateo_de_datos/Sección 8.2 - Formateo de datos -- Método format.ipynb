# %% [markdown]
# ### El método format()

# %% [markdown]
# ![Formateo%20numeros%20y%20cadenas.png](attachment:Formateo%20numeros%20y%20cadenas.png)

# %% [markdown]
# ![format.png](attachment:format.png)

# %% [markdown]
# #### Ordenamiento de los argumentos

# %%
print("Numero entero {}".format(42))

# %%
print("Provincia de la Argentina: {}".format('Cordoba'))

# %%
# Ordenamiento por defecto
"Compré {} {} a ${} por un total de ${}".format(6, 'bananas', 500, 3000)

# %%
# Ordenamiento especificado
"Por un total de ${3} compre {0} {1} a ${2} cada una.".format(6, 'bananas', 500, 3000)

# %%
# Dar formato a los números
print('Compré {:3d} {:8s} a ${:.3f} por un total de ${:.5f}'.
      format(6, 'bananas', 100.00, 600))

# %%
# Ordenamiento especificado y formateo
print('Por un total de ${3:.5f} compré {0:3d} {1:8s} a ${2:.3f} '.
      format(6, 'bananas', 100.00, 600))

# %%
# Porcentaje
'{:.2f}%'.format(10.12345)

# %%
# Con palabras clave
print('Compré {cantidad} {item} a ${precio_unitario} por un total de ${total}'.
      format(cantidad=6, item='bananas', precio_unitario=100.00, total=600))

# %%
# Declarar las variables por aparte
cantidad = 6
item = 'bananas'
precio_unitario = 100
total = cantidad * precio_unitario
print('Compré {a} {b} a ${c} por un total de ${d}'.format(a=cantidad, b=item, c=precio_unitario, d=total))

# %% [markdown]
# #### Ajuste del espacio

# %%
# Agregar espacios u otro carácter a la izquierda hasta alcanzar 9 dígitos
'{:>9}'.format(3.14)

# %%
# Reservar espacio para 20 caracteres y alinear sobre el margen derecho
'{:>20} '.format('Python')

# %%
# Reservar espacio para 20 caracteres y alinear sobre el margen izquierdo
'{:20} '.format('Python')

# %%
# Reservar espacio para 20 caracteres y centrar
'{:^20} '.format('Python')
